# %% [markdown]
# **Using this template**
#
# 1. Change notebook title to assignment title you working on, eg. `Graded Challenge 1 or Milestone 1`
# 2. Put your identity such as name and batch number below notebook title.
# 3. Write your description before do any work. State your purpose of this assignment and what you are trying to achieve.
# 4. Look at the rubric of this assignment and make sure you understand the criteria.
# 5. Code your solution in the cell provided below the working area section.
# 6. State your conlusions, findings, and any other relevant information in the cell provided below the conclusions sections.
# 7. Save this notebook and rename it to assignment title you working on  eg. `Graded Challenge 1 or Milestone 1`
# 8. Push your assignment before deadline.
# 9. Good Luck!

# %% [markdown]
# # Notebook Title
#
# Graded Challenge 1
#
# Nama    : Luvi Puspitasari
# Batch   : 11

# %%
df = pd.read_csv('Pokemon.csv')

# %% [markdown]
# ## Description
#
# ### Objective
#
# - Mampu memuat data dengan Pandas
# - Mampu menangani missing values pada dataset
# - Mampu melakukan manipulasi kolom
# - Mampu membuat query terhadap dataset
# - Mampu melakukan grouping terhadap dataset
# - Mampu melakukan visualisasi sederhana menggunakan Pandas
#
# ### Problem Statement
#
# Menganalisa data Pokemon

# %% [markdown]
# ## Working Area
#
# ```txt
# Put your code, analysis, everything below this line
#
# Make sure to check everything the rubric requires before you submit
# ```

# %% [markdown]
# ## II. Import Library

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## III. Loading Data

# %%
print (df)
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Melihat Info dasar pada sebuah Data Load
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 69.7+ KB

# %%
# Gambaran informasi dasar untuk data
df.describe().T
# Out:
#             count       mean         std    min     25%    50%     75%    max
# #           800.0  362.81375  208.343798    1.0  184.75  364.5  539.25  721.0
# Total       800.0  435.10250  119.963040  180.0  330.00  450.0  515.00  780.0
# HP          800.0   69.25875   25.534669    1.0   50.00   65.0   80.00  255.0
# Attack      800.0   79.00125   32.457366    5.0   55.00   75.0  100.00  190.0
# Defense     800.0   73.84250   31.183501    5.0   50.00   70.0   90.00  230.0
# Sp. Atk     800.0   72.82000   32.722294   10.0   49.75   65.0   95.00  194.0
# Sp. Def     800.0   71.90250   27.828916   20.0   50.00   70.0   90.00  230.0
# Speed       800.0   68.27750   29.060474    5.0   45.00   65.0   90.00  180.0
# Generation  800.0    3.32375    1.661290    1.0    2.00    3.0    5.00    6.0

# %%
# Data Keseluruhan

pd.set_option('display.max.column', None)
df
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
# Melihat jumlah baris dan kolom pada dataset
df.shape
# Out:
# (800, 13)

# %%
# Setting 10 Data teratas

df.head(10)
# Out:
#    #                       Name Type 1  Type 2  Total  HP  Attack  Defense  \
# 0  1                  Bulbasaur  Grass  Poison    318  45      49       49
# 1  2                    Ivysaur  Grass  Poison    405  60      62       63
# 2  3                   Venusaur  Grass  Poison    525  80      82       83
# 3  3      VenusaurMega Venusaur  Grass  Poison    625  80     100      123
# 4  4                 Charmander   Fire     NaN    309  39      52       43
# 5  5                 Charmeleon   Fire     NaN    405  58      64       58
# 6  6                  Charizard   Fire  Flying    534  78      84       78
# 7  6  CharizardMega Charizard X   Fire  Dragon    634  78     130      111
# 8  6  CharizardMega Charizard Y   Fire  Flying    634  78     104       78
# 9  7                   Squirtle  Water     NaN    314  44      48       65
#
#    Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0       65       65     45           1      False
# ...

# %%
# Setting 10 data yang tertampil

df.tail(10)
# Out:
#        #                 Name   Type 1  Type 2  Total   HP  Attack  Defense  \
# 790  714               Noibat   Flying  Dragon    245   40      30       35
# 791  715              Noivern   Flying  Dragon    535   85      70       80
# 792  716              Xerneas    Fairy     NaN    680  126     131       95
# 793  717              Yveltal     Dark  Flying    680  126     131       95
# 794  718     Zygarde50% Forme   Dragon  Ground    600  108     100      121
# 795  719              Diancie     Rock   Fairy    600   50     100      150
# 796  719  DiancieMega Diancie     Rock   Fairy    700   50     160      110
# 797  720  HoopaHoopa Confined  Psychic   Ghost    600   80     110       60
# 798  720   HoopaHoopa Unbound  Psychic    Dark    680   80     160       60
# 799  721            Volcanion     Fire   Water    600   80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 790       45       40     55           6      False
# ...

# %% [markdown]
# ## IV. Cleaning Data

# %%
# Mencari missing value pada Data

pokemon = df.copy()

# %%
pokemon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           800 non-null    int64
#  1   Name        800 non-null    object
#  2   Type 1      800 non-null    object
#  3   Total       800 non-null    int64
#  4   HP          800 non-null    int64
#  5   Attack      800 non-null    int64
#  6   Defense     800 non-null    int64
#  7   Sp. Atk     800 non-null    int64
#  8   Sp. Def     800 non-null    int64
#  9   Speed       800 non-null    int64
#  10  Generation  800 non-null    int64
#  11  Legendary   800 non-null    bool
# dtypes: bool(1), int64(9), object(2)
# memory usage: 69.7+ KB

# %%
#Mengetahui letak missing value

df.isna().sum()
# Out:
# #             0
# Name          0
# Type 1        0
# Total         0
# HP            0
# Attack        0
# Defense       0
# Sp. Atk       0
# Sp. Def       0
# Speed         0
# Generation    0
# Legendary     0
# dtype: int64

# %%
rows_without_missing_data.shape
# Out:
# (414, 13)

# %% [markdown]
# ## V. Explorating Data

# %%
# Menghapus Kolom yang banyak missing value

df.drop('Type 2', axis=1, inplace=True)

# %%
# Mengganti Nama Pada Data dan Kolom serta Menghapus Kolom Weakness

renamed_pokemon = pokemon.rename(
    columns={"#": "No.", "Type 1": "Strength", "Type 2": "Weakness", "Total": "Total Score", "HP": "Hit Point", "Attack": "Basic Attack", "Defense": "Basic Defense", "Sp. Atk": "Special Attack", "Sp. Def": "Special Defense", "Speed": "Speed (EV)", "Generation": "Generation of Pokemon", "Legendary": "Legendary of Pokemon"}, inplace=True)

# %%
#Panda Visualization

pokemon
# Out:
#      No.                   Name Strength  Total Score  Hit Point  \
# 0      1              Bulbasaur    Grass          318         45
# 1      2                Ivysaur    Grass          405         60
# 2      3               Venusaur    Grass          525         80
# 3      3  VenusaurMega Venusaur    Grass          625         80
# 4      4             Charmander     Fire          309         39
# ..   ...                    ...      ...          ...        ...
# 795  719                Diancie     Rock          600         50
# 796  719    DiancieMega Diancie     Rock          700         50
# 797  720    HoopaHoopa Confined  Psychic          600         80
# 798  720     HoopaHoopa Unbound  Psychic          680         80
# 799  721              Volcanion     Fire          600         80
#
#      Basic Attack  Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 0              49             49              65               65          45
# ...

# %%
pokemon
# Out:
#      No.                   Name Strength  Total Score  Hit Point  \
# 0      1              Bulbasaur    Grass          318         45
# 1      2                Ivysaur    Grass          405         60
# 2      3               Venusaur    Grass          525         80
# 3      3  VenusaurMega Venusaur    Grass          625         80
# 4      4             Charmander     Fire          309         39
# ..   ...                    ...      ...          ...        ...
# 795  719                Diancie     Rock          600         50
# 796  719    DiancieMega Diancie     Rock          700         50
# 797  720    HoopaHoopa Confined  Psychic          600         80
# 798  720     HoopaHoopa Unbound  Psychic          680         80
# 799  721              Volcanion     Fire          600         80
#
#      Basic Attack  Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 0              49             49              65               65          45
# ...

# %%
# Menampilkan Data Query Total Score diatas 500

current_Strength
# Out:
#      No.                       Name Strength  Total Score  Hit Point  \
# 2      3                   Venusaur    Grass          525         80
# 3      3      VenusaurMega Venusaur    Grass          625         80
# 6      6                  Charizard     Fire          534         78
# 7      6  CharizardMega Charizard X     Fire          634         78
# 8      6  CharizardMega Charizard Y     Fire          634         78
# ..   ...                        ...      ...          ...        ...
# 795  719                    Diancie     Rock          600         50
# 796  719        DiancieMega Diancie     Rock          700         50
# 797  720        HoopaHoopa Confined  Psychic          600         80
# 798  720         HoopaHoopa Unbound  Psychic          680         80
# 799  721                  Volcanion     Fire          600         80
#
#      Basic Attack  Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# ...

# %%
current_Strength.shape
# Out:
# (224, 12)

# %%
# Mencari Nama Pokemon yang Memiliki Total Score > 700, Special Attack > 100, dan Special Defense > 100
pokemon[
        (pokemon["Total Score"] > 700) &
        (pokemon["Special Attack"] > 100) &
        (pokemon["Special Defense"] >100)
]
# Out:
#      No.                 Name Strength  Total Score  Hit Point  Basic Attack  \
# 164  150  MewtwoMega Mewtwo Y  Psychic          780        106           150
# 422  382  KyogrePrimal Kyogre    Water          770        100           150
# 552  493               Arceus   Normal          720        120           120
#
#      Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 164             70             194              120         140
# 422             90             180              160          90
# 552            120             120              120         120
#
#      Generation of Pokemon  Legendary of Pokemon
# 164                      1                  True
# 422                      3                  True
# 552                      4                  True

# %%
# Mencari Score Hit Point, Basic Attack, dan Speed (EV) diatas 100 

pokemon[
        (pokemon["Hit Point"] > 100) &
        (pokemon["Basic Attack"] > 100) &
        (pokemon["Speed (EV)"] >100)
]
# Out:
#      No.                   Name Strength  Total Score  Hit Point  \
# 162  150                 Mewtwo  Psychic          680        106
# 163  150    MewtwoMega Mewtwo X  Psychic          780        106
# 164  150    MewtwoMega Mewtwo Y  Psychic          780        106
# 426  384  RayquazaMega Rayquaza   Dragon          780        105
# 493  445               Garchomp   Dragon          600        108
# 552  493                 Arceus   Normal          720        120
#
#      Basic Attack  Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 162           110             90             154               90         130
# 163           190            100             154              100         130
# 164           150             70             194              120         140
# 426           180            100             180              100         115
# 493           130             95              80               85         102
# ...

# %%
#Grouping and Aggregating

Score = pokemon["Total Score"]

# %%
#Score keseluruhan untuk 800 Pokemon adalah 

Score.sum()
# Out:
# 348082

# %%
pokemon.head(5)
# Out:
#    No.                   Name Strength  Total Score  Hit Point  Basic Attack  \
# 0    1              Bulbasaur    Grass          318         45            49
# 1    2                Ivysaur    Grass          405         60            62
# 2    3               Venusaur    Grass          525         80            82
# 3    3  VenusaurMega Venusaur    Grass          625         80           100
# 4    4             Charmander     Fire          309         39            52
#
#    Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 0             49              65               65          45
# 1             63              80               80          60
# 2             83             100              100          80
# 3            123             122              120          80
# 4             43              60               50          65
#
#    Generation of Pokemon  Legendary of Pokemon
# 0                      1                 False
# ...

# %%
# Mencari jumlah Score Hit Point pada setiap Kategori Strength

pokemon.groupby("Strength", sort=False) ["Hit Point"].sum()
# Out:
# Strength
# Grass       4709
# Fire        3635
# Water       8071
# Bug         3925
# Normal      7573
# Poison      1883
# Electric    2631
# Ground      2361
# Fairy       1260
# Fighting    1886
# Psychic     4026
# Rock        2876
# Ghost       2062
# Ice         1728
# Dragon      2666
# Dark        2071
# Steel       1761
# Flying       283
# Name: Hit Point, dtype: int64

# %%
#Mencari Data Hit Point disandingkan dengan Total Score dan Legendary of Pokemon

pokemon[
        (pokemon["Hit Point"] > 100) &
        (pokemon["Total Score"] > 500)
].groupby(["Hit Point", "Total Score"])["Legendary of Pokemon"].count()
# Out:
# Hit Point  Total Score
# 103        545            1
# 105        505            1
#            509            1
#            540            1
#            590            1
#            680            1
#            780            1
# 106        680            3
#            780            2
# 108        525            1
#            600            2
#            700            1
# 110        508            1
#            510            1
#            515            1
#            528            1
#            530            2
#            670            1
# 115        535            1
#            580            1
# 120        600            1
#            720            1
# 123        521            1
#            531            1
# 125        660            1
#            700            2
# 126        680            2
# 130        525            1
#            535            1
# 150        670            1
#            680            2
# 160        540            1
# ...

# %%
pokemon
# Out:
#      No.                   Name Strength  Total Score  Hit Point  \
# 0      1              Bulbasaur    Grass          318         45
# 1      2                Ivysaur    Grass          405         60
# 2      3               Venusaur    Grass          525         80
# 3      3  VenusaurMega Venusaur    Grass          625         80
# 4      4             Charmander     Fire          309         39
# ..   ...                    ...      ...          ...        ...
# 795  719                Diancie     Rock          600         50
# 796  719    DiancieMega Diancie     Rock          700         50
# 797  720    HoopaHoopa Confined  Psychic          600         80
# 798  720     HoopaHoopa Unbound  Psychic          680         80
# 799  721              Volcanion     Fire          600         80
#
#      Basic Attack  Basic Defense  Special Attack  Special Defense  Speed (EV)  \
# 0              49             49              65               65          45
# ...

# %%
# %matplotlib inline

# %%
#Memmbuat Grafik antara Pokemon dengan Strength Grass, dengan x = "Total Score" dan y = "Hit Point"
pokemon[pokemon["Strength"] == "Grass"].groupby("Total Score")["Hit Point"].sum().plot()
# Out:
# <AxesSubplot:xlabel='Total Score'>

# %%
#Mencari List Pokemon dengan "Strength" Flying beserta Angka Total Score dan Special Attack

pokemon[pokemon["Strength"] == "Flying"].groupby("Total Score")["Special Attack"].sum()
# Out:
# Total Score
# 245     45
# 535     97
# 580    235
# Name: Special Attack, dtype: int64

# %%
#Grafik Batang untuk kategori Strength Pokemon dari yang paling banyak sampai terkecil

pokemon["Strength"].value_counts().head(10).plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
pokemon["Strength"].value_counts().head(10)
# Out:
# Water       112
# Normal       98
# Grass        70
# Bug          69
# Psychic      57
# Fire         52
# Electric     44
# Rock         44
# Dragon       32
# Ground       32
# Name: Strength, dtype: int64

# %% [markdown]
# ## Conclusions, Assumptions, Overall Analysis
#
# `put your conclusions here`

# %% [markdown]
# - Dari data Pokemon diatas dapat disimpulkan bahwa terdapat "Strength" dengan kategori "Water" lebih banyak dibanding kategori yang lain.
# - Untuk missing value, ditemukan di kolom Type 2 yang berupa Weakness pada Pokemon
